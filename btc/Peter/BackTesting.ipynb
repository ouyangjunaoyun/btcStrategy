# %%
from enum import Enum
import pandas as pd
import glob
import matplotlib.pyplot as plt
from datetime import datetime, date
from BTCTools import BSTools, BTCBacktester
import pytz
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
option_url = 'raw_data/Backtest/option/deribit_btc.usd.2021-03-26.32000.call.gz'
underlying_url = 'raw_data/Backtest/future/BTC-26MAR21.csv'
index_url = 'raw_data/Backtest/index/2021-01_btc_usd_index.csv'

# %%
bt1 = BTCBacktester.BackTester(option_url, underlying_url, index_url, include_transaction_cost=False)
bt1.simulateData()
# Out:
# /Users/pzhao/miniconda3/lib/python3.6/site-packages/scipy/optimize/zeros.py:173: RuntimeWarning: derivative was zero.
#   warnings.warn(msg, RuntimeWarning)

# %%
bt2 = BTCBacktester.BackTester(option_url, underlying_url, index_url, include_transaction_cost=True)
bt2.simulateData()
# Out:
# /Users/pzhao/miniconda3/lib/python3.6/site-packages/scipy/optimize/zeros.py:173: RuntimeWarning: derivative was zero.
#   warnings.warn(msg, RuntimeWarning)
